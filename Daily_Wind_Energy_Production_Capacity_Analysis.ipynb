# %% [markdown]
# <a href="https://colab.research.google.com/github/red21steven/Daily-Wind-Energy-Production-Capacity-Analysis/blob/main/Daily_Wind_Energy_Production_Capacity_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In this project I've done some analysis and visualization on Daily Wind Energy Production Capacity of australia with the data available at [Aneroid Energy](https://anero.id/energy/wind-energy).
#
# **In this project I've built a web scraper to scrape the data from the public domain and made some analysis & visualization with the scraped data.**
#
# **This project gives the audience a live visual on the data from the website whenever it's updated all you need to do is just run each and every cell to get the new visual on the available data in an instant.**
#
# ***This project is a work in progress but all the visual given in this workspace is constantly checked and updated inorder to give the accurate visual analysis.***

# %%
#Imported the necessary packages and libraries
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import plotly.express as px
import pandas as pd
import requests
import csv

#This is the web scraper
request = requests.get('https://anero.id/energy/wind-energy')

soup = BeautifulSoup(request.text, 'html5lib')

wind_t = soup.select_one('table')

table_body = wind_t.select_one('tbody')

south_whales = table_body.select('tr')[1:17]

#print(south_whales)

queensland = table_body.select('tr')[19:21]

south_australia = table_body.select('tr')[23:45]

tasmania = table_body.select('tr')[47:51]

victoria = table_body.select('tr')[53:78]

csv_data = [['farm_Name', 'capacity']]

#This function is used to write the collected data into a CSV file 
def csv_writer():
  with open('Australia Dataset.csv', 'w') as file:
    write = csv.writer(file)
    write.writerows(csv_data)

def data_collection(country):
  try:
    for e in country:
      name = e.find_all('td')[1].text
      capacity = e.find_all('td')[3].text
      csv_data.append([name, capacity])
    csv_writer()
  except:
    print("Something went wrong")

#This function is for reading the generated csv file
def csv_reader(path, filename):
  return pd.read_csv(path+'/'+filename)

path = '/content'

#Run all the functions to get the energy capacity of austalia as a whole
#To get state wise data for the energy capacity of austalia run the below functions one by one and change the name of the csv for each dataset
#While running the below functions one by one comment out the rest of the function to get the dataset of a specific country

data_collection(south_whales)

data_collection(queensland)

data_collection(south_australia)

data_collection(tasmania)

data_collection(victoria)

aus_wind = csv_reader(path, 'Australia Dataset.csv')

sw = csv_reader(path, 'New South Whales Dataset.csv')

q =  csv_reader(path, 'Queensland Dataset.csv')

sa = csv_reader(path, 'South Australia Dataset.csv')

t = csv_reader(path, 'Tasmania Dataset.csv')

v = csv_reader(path, 'Victoria Dataset.csv')

# %%
aus_wind
# Out:
#                  farm_Name  capacity
# 0          Bango Wind Farm       159
# 1      Boco Rock Wind Farm       113
# 2      Bodangora Wind Farm       113
# 3        Capital Wind Farm       140
# 4    Collector Wind Farm 1       228
# ..                     ...       ...
# 64    Salt Creek Wind Farm        54
# 65        Waubra Wind Farm       192
# 66        Yambuk Wind Farm        30
# 67        Yendon Wind Farm       144
# 68  Yaloak South Wind Farm        29
#
# [69 rows x 2 columns]

# %%
fig = px.line(aus_wind, x="farm_Name", y="capacity", template='plotly_dark', title="Total Wind Energy Capacity In Australia Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6d385f3a-ab9f-46e3-b594-60d65e967175" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6d385f3a-ab9f-46e3-b594-60d65e967175")) {
#                     Plotly.newPlot(
#                         '6d385f3a-ab9f-46e3-b594-60d65e967175',
# ...

# %%
#First half of the above line graph for a better view
fig = px.line(aus_wind.head(30), x="farm_Name", y="capacity", template='plotly_dark', title="Total Wind Energy Capacity In Australia Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="66200295-5b5e-4813-8d13-e88a3f0e16b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("66200295-5b5e-4813-8d13-e88a3f0e16b1")) {
#                     Plotly.newPlot(
#                         '66200295-5b5e-4813-8d13-e88a3f0e16b1',
# ...

# %%
#Second half of the total Energy capacity line graph for a better view
fig = px.line(aus_wind.tail(39), x="farm_Name", y="capacity", template='plotly_dark', title="Total Wind Energy Capacity In Australia Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cb40bfd9-fa15-4044-b7f3-cec948d50ebf" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb40bfd9-fa15-4044-b7f3-cec948d50ebf")) {
#                     Plotly.newPlot(
#                         'cb40bfd9-fa15-4044-b7f3-cec948d50ebf',
# ...

# %%
sw
# Out:
#                          farm_Name  capacity
# 0                  Bango Wind Farm       159
# 1              Boco Rock Wind Farm       113
# 2              Bodangora Wind Farm       113
# 3                Capital Wind Farm       140
# 4            Collector Wind Farm 1       228
# 5            Crookwell 2 Wind Farm        96
# 6          Crudine Ridge Wind Farm       141
# 7         Cullerin Range Wind Farm        30
# 8           Gullen Range Wind Farm       276
# 9           Gullen Range Wind Farm         0
# 10               Gunning Wind Farm        46
# 11              Sapphire Wind Farm       270
# 12             Silverton Wind Farm       199
# 13               Taralga Wind Farm       107
# 14              Woodlawn Wind Farm        48
# 15  White Rock Wind and Solar Farm       175

# %%
fig = px.bar(sw, x="farm_Name", y="capacity", template='plotly_dark', title="Energy Capacity In New South Wales Wind Farms Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="98e931de-7513-4154-a7e0-80ccba761bc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("98e931de-7513-4154-a7e0-80ccba761bc1")) {
#                     Plotly.newPlot(
#                         '98e931de-7513-4154-a7e0-80ccba761bc1',
# ...

# %%
q
# Out:
#                  farm_Name  capacity
# 0    Coopers Gap Wind Farm       452
# 1  Mount Emerald Wind Farm       180

# %%
fig = px.bar(q, x="farm_Name", y="capacity", template='plotly_dark', title="Energy Capacity In Queensland Wind Farms Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4b709906-8336-4a36-a27d-5df6e1eaaecc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4b709906-8336-4a36-a27d-5df6e1eaaecc")) {
#                     Plotly.newPlot(
#                         '4b709906-8336-4a36-a27d-5df6e1eaaecc',
# ...

# %%
sa
# Out:
#                             farm_Name  capacity
# 0                 The Bluff Wind Farm        52
# 1                     Cathedral Rocks        66
# 2              Clements Gap Wind Farm        57
# 3                   Canunda Wind Farm        46
# 4                 Hallett 1 Wind Farm        94
# 5                 Hallett 2 Wind Farm        71
# 6                 Hornsdale Wind Farm       102
# 7               Hornsdale Wind Farm 2       102
# 8               Hornsdale Wind Farm 3       112
# 9               Lincoln Gap Wind Farm       212
# 10      Lake Bonney Wind Farm Stage 1        80
# 11       Lake Bonney Stage 2 Windfarm       159
# 12      Lake Bonney Stage 3 Wind Farm        39
# 13                Mt Millar Wind Farm        70
# 14         North Brown Hill Wind Farm       132
# 15   Snowtown Wind Farm Stage 2 North       144
# 16           Snowtown South Wind Farm       126
# 17  Snowtown Wind Farm Units 1 And 47        99
# 18            Starfish Hill Wind Farm        34
# ...

# %%
fig = px.bar(sa, x="farm_Name", y="capacity", template='plotly_dark', title="Energy Capacity In South Australian Wind Farms Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="51a918d1-c3c1-4c88-bdc3-3184f8a2ad97" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("51a918d1-c3c1-4c88-bdc3-3184f8a2ad97")) {
#                     Plotly.newPlot(
#                         '51a918d1-c3c1-4c88-bdc3-3184f8a2ad97',
# ...

# %%
t
# Out:
#                                         farm_Name  capacity
# 0                           Cattle Hill Wind Farm       148
# 1                     Granville Harbour Wind Farm       110
# 2                             Musselroe Wind Farm       168
# 3  Woolnorth Studland Bay / Bluff Point Wind Farm       140

# %%
fig = px.bar(t, x="farm_Name", y="capacity", template='plotly_dark', title="Energy Capacity In Tasmania Wind Farms Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7941d914-30de-4b5c-98e1-911f6634c86c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7941d914-30de-4b5c-98e1-911f6634c86c")) {
#                     Plotly.newPlot(
#                         '7941d914-30de-4b5c-98e1-911f6634c86c',
# ...

# %%
v
# Out:
#                                farm_Name  capacity
# 0                       Ararat Wind Farm       242
# 1                   Bald Hills Wind Farm       107
# 2                    Berrybank Wind Farm       181
# 3   Bulgana Green Power Hub - Units 1-50       182
# 4              Challicum Hills Wind Farm        52
# 5                  Cherry Tree Wind Farm        58
# 6                    Crowlands Wind Farm        80
# 7                   Dundonnell Wind Farm       168
# 8                   Dundonnell Wind Farm        46
# 9                   Dundonnell Wind Farm       121
# 10                      Elaine Wind Farm        84
# 11                       Kiata Wind Farm        31
# 12                   Macarthur Wind Farm       420
# 13                   Mt Mercer Wind Farm       131
# 14                Mortons Lane Wind Farm        20
# 15                   Moorabool Wind Farm       150
# 16               Mt Gellibrand Wind Farm       138
# ...

# %%
fig = px.bar(v, x="farm_Name", y="capacity", template='plotly_dark', title="Energy Capacity In Victoria Wind Farms Acording To Aneroid Energy")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e07a737b-c4c7-492d-b61f-e83ec78e6243" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e07a737b-c4c7-492d-b61f-e83ec78e6243")) {
#                     Plotly.newPlot(
#                         'e07a737b-c4c7-492d-b61f-e83ec78e6243',
# ...
